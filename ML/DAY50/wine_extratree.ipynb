# %% [markdown]
# #### Ensemble - RandomForest & ExtraTree
# - 배깅 방식의 앙상블 ==> 중복 허용한 랜덤 샘플 + 동일 모델 (DT)
#     * 대표 알고리즘 : RandomForest
# - 페이스트 방식의 앙상블 ==> 랜덤 샘플 + 동일 모델 (DT)
#     * 대표 알고리즘 : ExtraTreeC/R

# %% [markdown]
# [목표] 와인 분류 => 0과 1 / 2개 종류 분류

# %% [markdown]
# [1] 모듈 로딩 및 데이터 준비

# %%
# 모듈 로딩
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 데이터
datafile = '../data/wine.csv'

wineDF = pd.read_csv(datafile)

# %%
# 데이터 확인
wineDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   alcohol  6497 non-null   float64
#  1   sugar    6497 non-null   float64
#  2   pH       6497 non-null   float64
#  3   class    6497 non-null   float64
# dtypes: float64(4)
# memory usage: 203.2 KB

# %%
wineDF.head()
# Out:
#    alcohol  sugar    pH  class
# 0      9.4    1.9  3.51    0.0
# 1      9.8    2.6  3.20    0.0
# 2      9.8    2.3  3.26    0.0
# 3      9.8    1.9  3.16    0.0
# 4      9.4    1.9  3.51    0.0

# %%
# 타겟/라벨의 클래스 분포
wineDF['class'].value_counts()
# Out:
# class
# 1.0    4898
# 0.0    1599
# Name: count, dtype: int64

# %%
wineDF.describe()
# Out:
#            alcohol        sugar           pH        class
# count  6497.000000  6497.000000  6497.000000  6497.000000
# mean     10.491801     5.443235     3.218501     0.753886
# std       1.192712     4.757804     0.160787     0.430779
# min       8.000000     0.600000     2.720000     0.000000
# 25%       9.500000     1.800000     3.110000     1.000000
# 50%      10.300000     3.000000     3.210000     1.000000
# 75%      11.300000     8.100000     3.320000     1.000000
# max      14.900000    65.800000     4.010000     1.000000

# %% [markdown]
# [2] 학습 준비

# %%
# 학습용 & 테스트용 데이터셋 분할
from sklearn.model_selection import train_test_split

# %%
# 피쳐/독립변수와 타겟/라벨/종속변수 분리
featureDF = wineDF[wineDF.columns[:-1]]
targetSR = wineDF[wineDF.columns[-1]]

print(f'featureDF : {featureDF.shape}, {featureDF.ndim}D    targetSR : {targetSR.shape}, {targetSR.ndim}D')
# Out:
# featureDF : (6497, 3), 2D    targetSR : (6497,), 1D

# %%
# 학습용, 테스트용 데이터셋 분리
X_train, X_test, y_train, y_test = train_test_split(featureDF, targetSR, test_size=0.2, stratify=targetSR, random_state=1)

# %%
X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)

y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# %%
print(f'X_train : {X_train.shape}   y_train : {y_train.shape}')
print(f'X_test : {X_test.shape}   y_test : {y_test.shape}')
# Out:
# X_train : (5197, 3)   y_train : (5197,)
# X_test : (1300, 3)   y_test : (1300,)

# %% [markdown]
# [3] 학습 진행

# %%
# 학습방법 : 지도학습 > 분류
# 알고리즘 : 앙상블 > 페이스팅
from sklearn.ensemble import ExtraTreesClassifier

# %%
# 인스턴스 생성 => 100개의 내부 DT모델에서 사용할 데이터셋 생성
#                 random_state 매개변수 설정으로 고정된 데이터셋 생성
et_model = ExtraTreesClassifier(random_state=7)

# 학습
et_model.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(random_state=7)

# %%
# 모델 파라미터
print(f'classes_             : {et_model.classes_}')
print(f'n_classes_           : {et_model.n_classes_}개')
print()
print(f'feature_names_in_    : {et_model.feature_names_in_}')
print(f'n_features_in_       : {et_model.n_features_in_}개')
print(f'feature_importances_ : {et_model.feature_importances_}')
# Out:
# classes_             : [0. 1.]
# n_classes_           : 2개
#
# feature_names_in_    : ['alcohol' 'sugar' 'pH']
# n_features_in_       : 3개
# feature_importances_ : [0.18992806 0.53030305 0.2797689 ]

# %%
# 모델 파라미터
print(f'clasees         : {et_model.estimator_}')
for est in et_model.estimators_ : print(est)
# Out:
# clasees         : ExtraTreeClassifier()
# ExtraTreeClassifier(random_state=327741615)
# ExtraTreeClassifier(random_state=976413892)
# ExtraTreeClassifier(random_state=1202242073)
# ExtraTreeClassifier(random_state=1369975286)
# ExtraTreeClassifier(random_state=1882953283)
# ExtraTreeClassifier(random_state=2053951699)
# ExtraTreeClassifier(random_state=959775639)
# ExtraTreeClassifier(random_state=1956722279)
# ExtraTreeClassifier(random_state=2052949340)
# ExtraTreeClassifier(random_state=1322904761)
# ExtraTreeClassifier(random_state=165338510)
# ExtraTreeClassifier(random_state=1133316631)
# ExtraTreeClassifier(random_state=4812360)
# ExtraTreeClassifier(random_state=372560217)
# ExtraTreeClassifier(random_state=309457262)
# ExtraTreeClassifier(random_state=1801189930)
# ExtraTreeClassifier(random_state=1152936666)
# ExtraTreeClassifier(random_state=68334472)
# ExtraTreeClassifier(random_state=2146978983)
# ExtraTreeClassifier(random_state=119248870)
# ...

# %% [markdown]
# [4] 성능평가

# %%
train_score = et_model.score(X_train, y_train)
test_score = et_model.score(X_test, y_test)

# %%
print(f'train_score : {train_score}     test_score : {test_score}')
# Out:
# train_score : 0.9973061381566288     test_score : 0.8961538461538462

# %% [markdown]
# [5] 튜닝

# %% [markdown]
# - RandomizedSearchCV 하이퍼파라미터 최적화 클래스
#     * 범위가 넓은 하이퍼파라미터 설정에 좋음
#     * 지정된 범위에서 지정된 횟수만큼 하이퍼파라미터를 추출하여 조합 진행

# %%
# 모듈 로딩
from sklearn.model_selection import RandomizedSearchCV

# %%
# RandomForestClassifier 하이퍼파라미터 설정
params = {'max_depth': range(2,16), 'min_samples_leaf':range(5,16), 'criterion':['gini', 'entropy', 'log_loss']}

# %%
et_model = ExtraTreesClassifier(n_estimators=300,random_state=7)

# %%
searchCV = RandomizedSearchCV(et_model, param_distributions=params, n_iter=50, verbose=4)

# %%
searchCV.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END criterion=log_loss, max_depth=12, min_samples_leaf=15;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=12, min_samples_leaf=15;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=12, min_samples_leaf=15;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=12, min_samples_leaf=15;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=12, min_samples_leaf=15;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=14, min_samples_leaf=6;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=14, min_samples_leaf=6;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=14, min_samples_leaf=6;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=14, min_samples_leaf=6;, score=0.754 total time=   0.2s
# ...

# %%
# 모델 파라미터
print(f'best_score_ : {searchCV.best_score_}')
print(f'best_params_ : {searchCV.best_params_}')
print(f'best_estimator_ : {searchCV.best_estimator_}')

cv_resultDF = pd.DataFrame(searchCV.cv_results_)
cv_resultDF
# Out:
# best_score_ : 0.75389649811209
# best_params_ : {'min_samples_leaf': 5, 'max_depth': 12, 'criterion': 'gini'}
# best_estimator_ : ExtraTreesClassifier(max_depth=12, min_samples_leaf=5, random_state=7)
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.116730      0.014354         0.013317        0.001765
# 1        0.100255      0.006775         0.011356        0.001141
# 2        0.086337      0.005699         0.011280        0.003171
# 3        0.085063      0.006072         0.009728        0.001329
# 4        0.090642      0.006672         0.010091        0.001278
# 5        0.102363      0.019073         0.010212        0.002034
# 6        0.082718      0.002847         0.009451        0.001010
# 7        0.100760      0.022020         0.010165        0.001459
# 8        0.090319      0.002830         0.010598        0.001037
# 9        0.083942      0.001631         0.009404        0.000806
# ...
