# %% [markdown]
# #### 경제 관련 낚시성 기사 탐지 모델
# - 데이터 : json 파일
# - 피처 : 뉴스 기사 제목, 본문
# - 타겟 : 낚시성 기사 여부

# %%
### 모듈 로딩
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torch import optim
import torch.optim.lr_scheduler as lr_scheduler

from konlpy.tag import *

from collections import Counter
from custom import *

import os
import re
import pickle

import pandas as pd
import json
import numpy as np

# %%
file_path = './data/'

# %%
label_list = os.listdir(file_path)
print(label_list)
# Out:
# ['0', '1']

# %%
dict = {'text' : [] , 'label' : []}
for num in label_list:
    folder_path = file_path+num
    file_list = os.listdir(folder_path)
    for file in file_list:
        with open(folder_path+'/'+file, encoding='utf-8') as f:
            data = json.load(f)
            df = pd.json_normalize(data, record_path=["sourceDataInfo","sentenceInfo"])
            
            data = df['sentenceContent'].to_string()
            # 한글만 남기기 + 공백 여러개 -> 1개로 변환
            data = re.sub(r'[^ㄱ-힣\s]', '', data)
            data = re.sub(r'\s', ' ', data)

            dict['text'].append(data)
            dict['label'].append(int(num))

print(len(dict['text']), len(dict['label']))
# Out:
# 41082 41082

# %%
textDF = pd.DataFrame(dict)
textDF.head()
# Out:
#                                                 text  label
# 0       금융권이 최근 한국임팩트금융을 설립해 본격 활동을 시작한 데 이어 소외계층...      0
# 1              열린 마음으로 미래를 내다보고 인재를 중시하자 미래에셋의 경영...      0
# 2       포용적 금융 이란 저소득층 소상공인 농민       또한 이자 부담 완화 ...      0
# 3       전 세계 기업들이 해킹으로 몸살을 앓고 있는 가운데 일 커뮤니케이션즈네이트...      0
# 4                 연세대 지속가능발전포럼의 세션이 일 연세대학교 백양누리홀...      0

# %%
print(textDF['text'][0])
# Out:
#      금융권이 최근 한국임팩트금융을 설립해 본격 활동을 시작한 데 이어 소외계층 지원에       한국 임팩트금융이 본격 활동을 시작한 데 이어 금융권이 금융소외 계층 지원사업에 속      지난 월 설립추진위를 발족했던 임팩트금융 추진위원회는 최근 유한회사 한국임팩트 금      민간주도로 설립된 한국임팩트 금융은 억원대 자금을 조성해 금융소외계층과 사회      한국임팩트금융 위원장으로 추대된 이헌재 전 경제부총리는 사회적 변화가 빠르고 문      지난 발족식에서 개인적으로 주택문제에 관심이 있다는 이 위원장의 발언으로 볼      주거 외에도 한국임팩트금융은 보육 보건 환경 등 한국 사회의 핵심 이슈를 해결하      그 밖에도 최종구 금융위원회 위원장은 지난 일장애인 금융 이용 제약 해소 방안                         고 밝히면서 그 움직임이 구체적으로 드러나고 있다      금융권이 문재인정부 출범 이후 강조되어 온 임팩트 금융의 첫 단추로 장애인 금     임팩트 금융은 사회적 약자를 포함한 모든 경제 주체가 저축 지급 결제 신용 보     이러한 분위기 속에서 금융권도 사회적 책임을 다하고 포용적 금융을 실천하기 위해 금     국민은행은 지난 월부터 사회적 배려가 필요한 장기 연체 채무자에 대한 금융 지     국민은행이 추진하는 금융 지원은 연체 기간이 오래 지난 특수 채권에 대한 채무 감면     특히 대상자 중 연대 보증으로 어려움을 겪는 사람들에 대해서는 최대 까지 감면     국민은행은 상환 의지가 있음에도 실업 불의의 사고 등으로 경제력을 상실해 채무 상                                 우리은행은 더 큰 금융을 내세웠다     이를 위해 포용적 생산적 신뢰의금융 등 개의 실무팀을 구성해 중금리 대출 확대     우리은행은 서민 금융 거점 점포를 개에서 개로 확대하고 서민 금융 지원 강화              장애인 노령자들을 위한 맞춤 서비스를 통해 편의성을 높이는 곳도 있다     신한은행은 지난 월 시니어 고객 상담 창구를 노인과 장애인을 위한 마음맞춤 창구     또한 수화 상담 서비스를 운영하고 거점 영업점에 장애인 전용 전화기를 배치하는 등      임팩트 투자 열풍 어떤 임팩트를 임팩트 금융 활성화를 위한 국내 사회의 움직임

# %%
# 훈련, 테스트용 데이터 나누기
train = textDF.sample(frac=0.9, random_state=10)
test = textDF.drop(train.index)

print(train.head(5).to_markdown())
print(len(train), len(test))
# Out:
# |       | text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |   label |
# |------:|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------:|
# | 25262 | 경제과학부 이상문 기자비트코인이 열풍을 지나 광풍으로 이어지고 있다      가상화폐 관련 인터넷 카페에는 하루에도 수백건의 글이 올라오고 있고 주변에서도 가                            주부는 물론 학생까지 가상화폐 시장에 뛰어들었다      최근 비트코인 관련 카페에서 논란이 됐던 비트코인 플래티넘 사기 소동의 중심에       또한 가수 박정운씨가 가상화폐 채굴기에 투자하면 수익금을 가상화폐로 돌려주겠      상황이 이렇게 되자 금융당국은 투기 조장과 자금세탁 등을 이유로 제동을 걸겠다는 입      최종구 금융위원장은 가상화폐는 화폐가 아니다 금융거래가 아니기 때문에 가상화폐      가상화폐의 금전적 가치를 인정할 수 없기 때문에 제도권 안에 두고 규제하지는 않겠다                            금융위 주도로 가상화폐 규제안도 추진 중이다      기본적으로 가상화폐 거래 행위를 유사수신행위로 보고 원칙적으로 금지하는 것이 골자지     하지만 가상화폐 규제안 마련을 주도하고 있는 법무부는 가상화폐 거래를 전면금지해야     현재 정부 규제안은 전면금지가 아닌 거래소와 투자자의 자격 요건 강화 등으로 조율될     기존 금융위의 규제안은 거래소에만 자격 요건을 뒀는데 투자자에 대한 자격요건도 강                                       과세논의까지 이뤄지고 있다                                    무조건적인 규제가 정답은 아니다     이미 가상화폐 거래소 규모가 수조원대에 육박해 거래가 전면 금지될 경우 상당한 투자                               미국이나 일본은 가상화폐를 인정하고 있다     다만 투자자 보호를 위한 규제와 자금세탁 등 불법행위를 엄격히 규제하겠다는 단서 조     비트코인 등 가상화폐는 국가간 장벽이 없어 금융당국이 거래를 막으면 다른 나라 거래                  더욱이 암호화폐와 블록체인 기술산업 발전에도 영향을 줄 수 있다     금융당국은 무조건적인 규제만이 아니라 자칫 투기장으로 변질될 수 있는 시장을 바로                                                                                                                                                                                                                                                                                                                                                             |       1 |
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |       1 |
# | 41062 | 현대자동차그룹은  부산세계박람회 유치에 대한 범국민적 관심과 유치 열기를      일 현대차에 따르면 오는 일 프레스데이를 시작으로 일부터 일까지 모터      부산국제모터쇼 현대차 및 기아 공식 부스의 대형  전광판을 활용해 박람회 공식      박람회 유치위원회의 공식 홍보 영상에는 부산의 비전과 경쟁력 등을 알리는 내용이 담      현대차기아 공식 부스의 초대형 사이즈 전광판을 통해 상영돼 관람객들의 눈길을 사로      박람회 개최 시 국내 경제에 미치는 효과 등을 소개한 유치위의 공식 홍보 리플릿을       현대차그룹은 부산국제모터쇼가 부산세계박람회 유치에 대한 국민적 관심을      년 이후 년 만에 개최되는 이번 부산국제모터쇼에는 현대차 아이오닉       또한 현대차는 올 하반기부터 브랜드 체험관 현대 모터스튜디오 부산 및 고양에서       캠페인에 동참한 내방 고객들을 대상으로 현대 모터스튜디오 브랜드 굿즈 할인 혜택을      국제박람회기구 회원국의 주요 인사 방한 시 현대 모터스튜디오 등에 초청해 세계박람회     또한 국내외 네트워크와 판매 거점을 중심으로 부산세계박람회 유치 지원 활동을     국내에서는 부산을 포함한 주요 현대차 기아 판매 거점에 박람회 공식 홍보 리플릿을                  박람회 유치 붐업 분위기 조성에는 그룹사 스포츠 구단도 참여한다     올 하반기 중 기아 타이거즈와 전북 현대모터스  선수 유니폼에 박람회 유치 기원     해외에서는 글로벌 네트워크를 기반으로 아시아 미주 유럽 등 국제박람회기구 회원국     현대차그룹은 임원급 이상 주요 해외 법인 출장 시 박람회 유치 활동을 현지에서 전     현대차그룹은 지난해 월 국내 대기업 가운데 가장 먼저 그룹 차원의 내부 전담 조직     지난달 일현지시간 프랑스 파리 국제박람회기구 총회장에서 진행된 박람회 유치             양 연구원은 자신이 직접 수행한 차세대 미래 모빌리티 연구 사례를 소개했다     양 연구원의 발표는 회원국 대표들을 대상으로 부산세계박람회가 지향하는 인류와 기술      이와 함께 지난 월 국제박람회기구 총회가 개최된 프랑스 파리에서 박람회 로고를 래     기아는 파리 현지 판매 거점에서 홍보 영상을 노출하고 리플릿을 배포하는 등 현지 네     현대차그룹은 지난 일 중남미 주요 여개국 장차관급 고위 인사들을 현대 모터     현대차 관계자는 세계박람회는 상당한 경제 사회문화적 효과 창출이 기대되는 핵심 |       1 |
# 36974 4108

# %%
# 불용어 리스트 생성
stop_path = './stopwords.txt'

# %%
with open(stop_path, 'r', encoding='utf-8') as f:
    wordlist = f.readlines()
wordlist
# Out:
# ['프\n',
#  '뗴\n',
#  '잠시\n',
#  '채\n',
#  '즉시\n',
#  '드\n',
#  '하도록시키다\n',
#  '제\n',
#  '하는바\n',
#  '쓰\n',
#  '으로써\n',
#  '연이서\n',
#  '삐\n',
#  '결론을 낼 수 있다\n',
#  '지만\n',
#  '조용히\n',
#  '보는데서\n',
#  'ㅟ\n',
#  'ㅘ\n',
#  '탸\n',
#  '깨\n',
#  '똬\n',
#  '여보세요\n',
#  '잇따라\n',
#  'ㅐ\n',
#  '삼\n',
#  '거바\n',
#  '이 때문에\n',
#  '소생\n',
#  '쉿\n',
#  '함께\n',
#  '난\n',
#  '정도에 이르다\n',
#  '언제\n',
#  '괴\n',
#  '매번\n',
#  '하는 김에\n',
#  '거기\n',
#  '초\n',
#  '까\n',
#  '바꾸어말하자면\n',
#  '솨\n',
#  '처\n',
#  '꾸\n',
#  '까닭으로\n',
#  '그럼에도\n',
#  '아이참\n',
#  '곳\n',
#  '더욱더\n',
#  '그중에서\n',
#  '흥\n',
#  '양자\n',
#  '차\n',
#  'ㅈ\n',
#  '라서\n',
#  '나\n',
#  '비로소\n',
#  '쐬\n',
#  '요만한걸\n',
#  '이 외에\n',
#  '허\n',
#  '하는 것도\n',
#  '겨\n',
#  '절대\n',
#  '지든지\n',
#  '하물며\n',
#  '요만한 것\n',
#  '좌\n',
#  '지말고\n',
#  '이리하여\n',
#  '좋아\n',
#  '이었다\n',
#  '하네요\n',
#  '따위\n',
#  '아하\n',
#  '할때\n',
#  '그렇지만\n',
#  '두\n',
#  '어떻게\n',
#  '내일\n',
#  '퐈\n',
#  '료\n',
#  '무엇때문에\n',
#  '종\n',
#  '게\n',
#  '버\n',
#  '하기에\n',
#  '하기 보다는\n',
#  '한켠으로는\n',
#  '시각\n',
#  '펴\n',
#  '만은 아니다\n',
#  '심지어\n',
#  '설\n',
#  '도달하다\n',
#  '퍽\n',
#  'ㅒ\n',
#  '겹\n',
#  '어기여차\n',
#  '에도\n',
#  '트\n',
#  '타인\n',
#  '나왔는데\n',
#  '볘\n',
#  '퇴\n',
#  '세상에\n',
#  '외에도\n',
#  '서\n',
#  '당신들\n',
#  'ㅁ\n',
#  '이와 반대로\n',
#  '어이\n',
#  '일단\n',
#  '이봐\n',
#  'ㅛ\n',
#  '띠\n',
#  '어찌됐든\n',
#  '마저도\n',
#  '떼\n',
#  '뽜\n',
#  '책\n',
#  '톼\n',
#  '만\n',
#  '떠\n',
#  '할 수 있다\n',
#  '아무런\n',
#  '아무\n',
#  'ㄹ\n',
#  '니\n',
#  '우선\n',
#  '정\n',
#  '튜\n',
#  '뜨\n',
#  '그위에\n',
#  '간\n',
#  '반대로\n',
#  '본대로\n',
#  '뻐\n',
#  '한데\n',
#  '월\n',
#  '기준으로\n',
#  '까악\n',
#  '끄\n',
#  '거\n',
#  '입각\n',
#  '례\n',
#  '땨\n',
#  '몇\n',
#  '시\n',
#  '아무데도\n',
#  '년\n',
#  '어찌 됐어\n',
#  '붜\n',
#  '하지 않도록\n',
#  '어째서\n',
#  '으로부터\n',
#  'ㅑ\n',
#  '어떤 것\n',
#  '아\n',
#  '한 이유는\n',
#  '가령\n',
#  '하도록하다\n',
#  '어찌하든지\n',
#  '전자\n',
#  '하하\n',
#  '쀼\n',
#  '그러니까\n',
#  '팍\n',
#  '왜냐하면\n',
#  '할 지경이다\n',
#  '응\n',
#  '얼\n',
#  '타\n',
#  '취\n',
#  '바꾸어\n',
#  '되\n',
#  '각각\n',
#  '어느해\n',
#  '하든지\n',
#  '같\n',
#  '툭\n',
#  '헤\n',
#  '구체적으로\n',
#  '데\n',
#  '너무\n',
#  '여부\n',
#  '시작하여\n',
#  '부\n',
#  '쮸\n',
#  '설령\n',
#  '즈\n',
#  '쿼\n',
#  '엄\n',
#  '누가 알겠는가\n',
#  '오직\n',
#  '쭈\n',
#  '쀠\n',
#  '보드득\n',
#  '해\n',
#  '동시에\n',
#  '한편\n',
#  '어떤것\n',
#  '에 달려 있다\n',
#  '우에 종합한 것과 같이\n',
#  '쫘\n',
#  '갖고 말하자면\n',
#  '해도좋다\n',
#  '하기는 한데\n',
#  '우리\n',
#  '이지만\n',
#  '칠\n',
#  '막\n',
#  '싸\n',
#  '답\n',
#  'ㅖ\n',
#  '퓨\n',
#  '사\n',
#  '죠\n',
#  '따지지 않다\n',
#  '대해서\n',
#  '스\n',
#  '이외에도\n',
#  '받은\n',
#  '라\n',
#  '하고도\n',
#  'ㅔ\n',
#  '일\n',
#  '도록\n',
#  '갔나\n',
#  '각\n',
#  '뵈\n',
#  '아슬아슬한\n',
#  '그치지 않다\n',
#  '둘\n',
#  '쿠\n',
#  '모두\n',
#  '하고 있다\n',
#  '바꿔 말하면\n',
#  '더욱이는\n',
#  '꺄\n',
#  '하지\n',
#  '팔\n',
#  '으\n',
#  '때\n',
#  '툐\n',
#  '전후\n',
#  '오자마자\n',
#  '틈타\n',
#  '뿨\n',
#  'ㅎ\n',
#  '코\n',
#  '듀\n',
#  '아래윗\n',
#  '한마디\n',
#  '저사람\n',
#  '저\n',
#  '비록\n',
#  '개의치 않고\n',
#  '괜\n',
#  '대해\n',
#  '바꾸어서 말하면\n',
#  '첫번째로\n',
#  '시초에\n',
#  '할만하다\n',
#  '뤼\n',
#  '뀌\n',
#  '어랏\n',
#  '덜\n',
#  '다시말하면\n',
#  '체\n',
#  '햐\n',
#  '남들\n',
#  '이리\n',
#  '슈\n',
#  '둬\n',
#  '먀\n',
#  '이와 같은\n',
#  '놀라다\n',
#  '쪄\n',
#  '또는\n',
#  '커\n',
#  '한다면\n',
#  '헐떡헐떡\n',
#  '해봐요\n',
#  '만약\n',
#  '쁘\n',
#  '그렇지\n',
#  '하는것이 낫다\n',
#  '다시 말하면\n',
#  '샤\n',
#  '그리고\n',
#  '이유만으로\n',
#  '쿵\n',
#  '그렇지 않으면\n',
#  '이렇게되면\n',
#  '케\n',
#  '휘\n',
#  '여러분\n',
#  '하기는한데\n',
#  '쎠\n',
#  '화\n',
#  '저희\n',
#  '하게 하다\n',
#  '생각한대로\n',
#  '셋\n',
#  '점에서 보아\n',
#  '동안\n',
#  '탕탕\n',
#  '할줄알다\n',
#  '즈음하여\n',
#  '한테\n',
#  '뀨\n',
#  '퉈\n',
#  '하지만\n',
#  '습니다\n',
#  '바꾸어 말하면\n',
#  '이사람\n',
#  '꿔\n',
#  '따라\n',
#  '다음\n',
#  '쭤\n',
#  '더불어\n',
#  '어느쪽\n',
#  '주\n',
#  '오호\n',
#  '늬\n',
#  '어떻해\n',
#  '시작\n',
#  '부탁\n',
#  '다만\n',
#  '기점으로\n',
#  '총적으로 보면\n',
#  '방\n',
#  '심\n',
#  '쑤\n',
#  '수\n',
#  '헉헉\n',
#  '어느\n',
#  '반면\n',
#  '뿐만아니라\n',
#  '이용하여\n',
#  '이에요\n',
#  '테\n',
#  '바로\n',
#  '비슷하다\n',
#  '뎨\n',
#  '토하다\n',
#  '여기\n',
#  '자신\n',
#  '추\n',
#  '름\n',
#  '졸졸\n',
#  '얼마만큼\n',
#  '해도 좋다\n',
#  '밖에 안 된다\n',
#  '게우다\n',
#  '전\n',
#  '듸\n',
#  '등등\n',
#  '때문에\n',
#  '부류의 사람들\n',
#  '근거로\n',
#  '그래도\n',
#  '영\n',
#  '그렇지않으면\n',
#  '이라면\n',
#  '갖고말하자면\n',
#  '하게될것이다\n',
#  '어찌하여\n',
#  '하기보다는\n',
#  '보\n',
#  'ㄸ\n',
#  '최\n',
#  '규\n',
#  '하고\n',
#  '할수있어\n',
#  '뷔\n',
#  '하겠는가\n',
#  '관련이 있다\n',
#  '토\n',
#  '어쩌면\n',
#  '상태\n',
#  '쿄\n',
#  '저쪽\n',
#  '뒤\n',
#  '믜\n',
#  '그때\n',
#  '기대여\n',
#  '라는\n',
#  '공\n',
#  '알\n',
#  '분명\n',
#  '할 줄 안다\n',
#  '아니라면\n',
#  '이분\n',
#  '계\n',
#  '요컨대\n',
#  '있다\n',
#  '하면서\n',
#  '해도된다\n',
#  '좍좍\n',
#  '쳬\n',
#  '여덟\n',
#  '동\n',
#  '쥐\n',
#  '가까스로\n',
#  '뾔\n',
#  '여차\n',
#  '벼\n',
#  '도\n',
#  '기\n',
#  '사람\n',
#  '루\n',
#  '저러나\n',
#  '것과 같이\n',
#  '쇼\n',
#  '혹시\n',
#  '느\n',
#  '밖에\n',
#  '어제\n',
#  '춰\n',
#  '그런 까닭에\n',
#  '캬\n',
#  '는\n',
#  '감\n',
#  '와우\n',
#  '운운\n',
#  '녀\n',
#  '하는 편이 낫다\n',
#  '알았어\n',
#  '마\n',
#  '어떤 것들\n',
#  '무슨\n',
#  '뚜\n',
#  '장\n',
#  '아이야\n',
#  '하면된다\n',
#  '무릎 쓰고\n',
#  '각종\n',
#  '끼익\n',
#  '엉엉\n',
#  '쬬\n',
#  '텨\n',
#  '여전히\n',
#  '하겠다고\n',
#  '비교적\n',
#  '하기 위하여\n',
#  '다섯\n',
#  '뮈\n',
#  '갑\n',
#  '챠\n',
#  '어느 해\n',
#  '앗\n',
#  '이천구\n',
#  '려\n',
#  '두번째로\n',
#  '라도\n',
#  '주저하지 않고\n',
#  '륙\n',
#  '너\n',
#  '혹은\n',
#  '한\n',
#  '븨\n',
#  '만이 아니다\n',
#  '넷\n',
#  '뿐만 아니라\n',
#  '임에 틀림없다\n',
#  '위해\n',
#  '히\n',
#  '만 못하다\n',
#  '비추어 보아\n',
#  '결국\n',
#  '끙끙\n',
#  '다시 말하자면\n',
#  '얼마간\n',
#  '빼\n',
#  '관계가 있다\n',
#  '패\n',
#  '쪠\n',
#  '뉘\n',
#  '랑\n',
#  '아이\n',
#  '날\n',
#  '그들\n',
#  '된이상\n',
#  '이와 같다\n',
#  '왜\n',
#  '당\n',
#  'ㅝ\n',
#  '리\n',
#  '뇌\n',
#  '을\n',
#  '에게\n',
#  '딩동\n',
#  '위하여\n',
#  '제외하고\n',
#  '및\n',
#  'ㅣ\n',
#  '야호\n',
#  '그렇지 않다면\n',
#  '백\n',
#  '얼마큼\n',
#  '래\n',
#  '쒸\n',
#  '싀\n',
#  '이건\n',
#  '오르다\n',
#  '로써\n',
#  '이젠\n',
#  '이천육\n',
#  '중의 하나\n',
#  '의해서\n',
#  '해야한다\n',
#  '이야기\n',
#  '으로\n',
#  '휴\n',
#  '퍼\n',
#  '문\n',
#  '이제\n',
#  '이렇게 말하자면\n',
#  '쪼\n',
#  '한참\n',
#  '관\n',
#  '져\n',
#  '내\n',
#  '천천히\n',
#  '다음으로\n',
#  '아울러\n',
#  '픠\n',
#  '아아\n',
#  '여섯\n',
#  '오로지\n',
#  'ㅇ\n',
#  '와 같은 사람들\n',
#  '틔\n',
#  '할지라도\n',
#  '푸\n',
#  '쏴\n',
#  '우리들\n',
#  '어느때\n',
#  '자기집\n',
#  '하려고하다\n',
#  '류\n',
#  '피\n',
#  '시초\n',
#  '께서\n',
#  '설마\n',
#  '헐\n',
#  '돼\n',
#  '끠\n',
#  '해야 한다\n',
#  '힘차게\n',
#  '쉬\n',
#  'ㅡ\n',
#  '그저\n',
#  '이때\n',
#  '어머\n',
#  '르\n',
#  '쪽으로\n',
#  '튀\n',
#  '언제부터\n',
#  '항상\n',
#  '아슬아슬\n',
#  '그렇게\n',
#  '하려고 하다\n',
#  '따라서\n',
#  '분\n',
#  '재\n',
#  '바꾸어서 한다면\n',
#  '어떠한\n',
#  '뤄\n',
#  '어떤\n',
#  '씌\n',
#  '진짜로\n',
#  '하면 된다\n',
#  '중의하나\n',
#  '뼤\n',
#  '습니까\n',
#  '다\n',
#  '마치\n',
#  '뒤따라\n',
#  '쳐\n',
#  '며\n',
#  '언젠가\n',
#  '묘\n',
#  '페\n',
#  '저더러\n',
#  '이쪽\n',
#  '껴\n',
#  '뗘\n',
#  '음\n',
#  '에\n',
#  '응당\n',
#  '다수\n',
#  '공동으로\n',
#  '안에\n',
#  '일반적으로\n',
#  '대하면\n',
#  '그 위에\n',
#  '짜\n',
#  '다음에\n',
#  '쮜\n',
#  '이렇게 많은 것\n',
#  '반대로 말하자면\n',
#  '바\n',
#  'ㅚ\n',
#  '부터\n',
#  '어쩔 수 없다\n',
#  '줄은 몰랏다\n',
#  '일것이다\n',
#  '쁴\n',
#  '졔\n',
#  '상대적으로\n',
#  '위해서\n',
#  '얼마나\n',
#  '궈\n',
#  '렷습\n',
#  '소인\n',
#  '대로 하다\n',
#  '겸\n',
#  '푀\n',
#  '구\n',
#  '의해\n',
#  '별\n',
#  '아무도\n',
#  'ㅠ\n',
#  '더욱\n',
#  '희\n',
#  '그러한즉\n',
#  '쎄\n',
#  '뉴\n',
#  '됨\n',
#  'ㄴ\n',
#  '워\n',
#  '하나\n',
#  '디\n',
#  '이천팔\n',
#  '어떤것들\n',
#  '이럴정도로\n',
#  '했어요\n',
#  '냐\n',
#  '즉\n',
#  '만세\n',
#  '아주\n',
#  '같다\n',
#  '저런\n',
#  '새\n',
#  '윙윙\n',
#  '저분\n',
#  '일지라도\n',
#  '아이고\n',
#  '결코\n',
#  '제각기\n',
#  '돠\n',
#  '눈\n',
#  '반드시\n',
#  '대해 말하자면\n',
#  '다른 방면으로\n',
#  '포\n',
#  '말하자면\n',
#  '카\n',
#  '관하여\n',
#  '것으로\n',
#  '와아\n',
#  '걸\n',
#  '예\n',
#  '기준\n',
#  '켸\n',
#  '예하면\n',
#  '인젠\n',
#  '당신\n',
#  '자\n',
#  'ㅏ\n',
#  '쨔\n',
#  '하다면\n',
#  '비\n',
#  '그에 따르는\n',
#  '꺼\n',
#  '조금\n',
#  '하지마라\n',
#  '므\n',
#  'ㄷ\n',
#  '하는것도\n',
#  '입각하여\n',
#  '와르르\n',
#  '저리\n',
#  '하여금\n',
#  '절\n',
#  '를\n',
#  '캐\n',
#  '훠\n',
#  '이러나\n',
#  '고려하면\n',
#  '까지 미치다\n',
#  '안 그러면\n',
#  '흐흐\n',
#  '누\n',
#  '아마\n',
#  '해서는 안된다\n',
#  '쟀튼\n',
#  '않기 위해서\n',
#  '베\n',
#  '하자마자\n',
#  '그럼에도 불구하고\n',
#  '허걱\n',
#  '쩨\n',
#  '메\n',
#  '반면에\n',
#  '정확히\n',
#  '표\n',
#  '할 생각이다\n',
#  '뚝뚝\n',
#  '전부\n',
#  '하\n',
#  '나머지는\n',
#  '요만큼\n',
#  '말할것도 없고\n',
#  '들\n',
#  'ㅓ\n',
#  '에 있다\n',
#  '인 듯하다\n',
#  '그\n',
#  '바와같이\n',
#  '마저\n',
#  '어쨋든\n',
#  '고로\n',
#  '할\n',
#  '쟈\n',
#  '뫼\n',
#  '이렇구나\n',
#  '빠\n',
#  '어김없이\n',
#  '매\n',
#  '이\n',
#  '꼬\n',
#  '쾨\n',
#  '육\n',
#  '쵸\n',
#  '얼마든지\n',
#  '에서의\n',
#  '설사\n',
#  '할 따름이다\n',
#  '댜\n',
#  '몌\n',
#  'ㅃ\n',
#  '쩌\n',
#  '게다가\n',
#  '같이\n',
#  '키\n',
#  '레\n',
#  '숴\n',
#  '쌔\n',
#  '쎼\n',
#  '뛰\n',
#  '그사람\n',
#  '만큼\n',
#  '딱\n',
#  '한적이있다\n',
#  '애\n',
#  '의해되다\n',
#  '흠\n',
#  '비하면\n',
#  '마음대로\n',
#  '뒤이어\n',
#  '일곱\n',
#  '바꾸어 말하자면\n',
#  '곧\n',
#  '저것\n',
#  '못\n',
#  '헉\n',
#  '단지\n',
#  '앞의것\n',
#  '바와 같으니\n',
#  '따\n',
#  '휘익\n',
#  '즤\n',
#  '흑\n',
#  '쓔\n',
#  '주로\n',
#  '누구\n',
#  '총적으로 말하면\n',
#  '하는 것이 낫다\n',
#  '뿐\n',
#  '톄\n',
#  '앞\n',
#  '흔들\n',
#  '아이구\n',
#  '이유\n',
#  '관계없이\n',
#  '회\n',
#  '관한\n',
#  '대\n',
#  '혜\n',
#  '뿌\n',
#  '훨씬\n',
#  '예컨대\n',
#  '이러한\n',
#  '거의\n',
#  '외\n',
#  '로\n',
#  '머\n',
#  '셔\n',
#  '등\n',
#  '이와같다면\n',
#  '크\n',
#  '속\n',
#  '본\n',
#  '입장에서\n',
#  '너희\n',
#  '릐\n',
#  '겸사겸사\n',
#  '퉤\n',
#  '해도 된다\n',
#  '츼\n',
#  '이가\n',
#  '뮤\n',
#  '일때\n',
#  '하더라도\n',
#  '찌\n',
#  '태\n',
#  '지지\n',
#  '그러니\n',
#  '이 밖에\n',
#  'ㅜ\n',
#  '갸\n',
#  '된 이상\n',
#  '그런\n',
#  '하고 있었다\n',
#  '뢰\n',
#  '기 위해\n',
#  '뿐이다\n',
#  '하는것만 못하다\n',
#  '정말\n',
#  '남\n',
#  '쑈\n',
#  '불구하고\n',
#  '미\n',
#  '뺘\n',
#  '비길수 없다\n',
#  '하기 때문에\n',
#  '배\n',
#  '아니나다를가\n',
#  '시간\n',
#  '건\n',
#  '어느 쪽\n',
#  '가\n',
#  '롸\n',
#  '과연\n',
#  '저기\n',
#  '하는 것만 못하다\n',
#  '쯰\n',
#  '아무거나\n',
#  '대체로\n',
#  '예를 들자면\n',
#  '어찌됏든\n',
#  '큐\n',
#  '가끔\n',
#  'ㅍ\n',
#  '써\n',
#  '였다\n',
#  '노\n',
#  '쇠\n',
#  '메쓰겁다\n',
#  '할망정\n',
#  '쏘\n',
#  '도착하다\n',
#  '관해서는\n',
#  '기타\n',
#  '에 한하다\n',
#  '있는\n',
#  '더군다나\n',
#  '하고있었다\n',
#  '향해서\n',
#  '상\n',
#  '폐\n',
#  '로부터\n',
#  '보다더\n',
#  '약간\n',
#  '이르기까지\n',
#  '그치지\n',
#  '움\n',
#  '인가\n',
#  '그들의\n',
#  '방금\n',
#  '줘\n',
#  '중에서\n',
#  '이렇게 되면\n',
#  '뇨\n',
#  '한 후\n',
#  '앞에서\n',
#  'ㄲ\n',
#  '엿튼\n',
#  '그렇게 함으로써\n',
#  '아이쿠\n',
#  '여보시오\n',
#  'ㅂ\n',
#  '구토하다\n',
#  '임\n',
#  '인\n',
#  'ㅗ\n',
#  '봐\n',
#  '투\n',
#  '더라도\n',
#  '하곤하였다\n',
#  '견지에서\n',
#  '녜\n',
#  '결과에 이르다\n',
#  '이래\n',
#  '할지언정\n',
#  '허허\n',
#  '평\n',
#  '후\n',
#  '어느 것\n',
#  '다른\n',
#  '실로\n',
#  '켜\n',
#  '하다\n',
#  '어찌\n',
#  '개\n',
#  '또\n',
#  '안\n',
#  '츄\n',
#  '의지하여\n',
#  '그리하여\n',
#  '이것\n',
#  '의\n',
#  '혼자\n',
#  '치\n',
#  '하여야\n',
#  '않기 위하여\n',
#  '하구나\n',
#  '으로 인하여\n',
#  '알 수 있다\n',
#  '이번\n',
#  '해요\n',
#  '빠르게\n',
#  '때가 되어\n',
#  '쳇\n',
#  '이러이러하다\n',
#  '우에 종합한것과같이\n',
#  '말할 것도 없고\n',
#  '츠\n',
#  '뷰\n',
#  '하도다\n',
#  '교\n',
#  '풔\n',
#  '꽈\n',
#  '든간에\n',
#  '막론하고\n',
#  '무릎쓰고\n',
#  '오\n',
#  '갈\n',
#  '들에게\n',
#  '비걱거리다\n',
#  '뵤\n',
#  '으악\n',
#  '롭\n',
#  '그녀\n',
#  '꾀\n',
#  '또한\n',
#  '어찌됏어\n',
#  '적\n',
#  '하지마\n',
#  '어디\n',
#  '까요\n',
#  '셰\n',
#  '작\n',
#  '그런데\n',
#  '과\n',
#  '밖에 안된다\n',
#  '아홉\n',
#  '긔\n',
#  '할뿐\n',
#  '무엇\n',
#  '령\n',
#  '하면 할수록\n',
#  '악\n',
#  '이와 같다면\n',
#  '까지\n',
#  '촤\n',
#  '우와\n',
#  '눠\n',
#  '후에\n',
#  '무렵\n',
#  '띄\n',
#  '뫄\n',
#  '아니었다면\n',
#  '조차도\n',
#  '삐걱\n',
#  '연관되다\n',
#  '됴\n',
#  '쒀\n',
#  '위에서 서술한바와같이\n',
#  '어때\n',
#  '뾰\n',
#  '브\n',
#  '불문하고\n',
#  '어\n',
#  '하지 않는다면\n',
#  '에서는\n',
#  ...]

# %%
stopwords = []
for word in wordlist:
    stopwords.append(word.replace('\n',''))
print(len(wordlist),len(stopwords))
print(stopwords[-10:])
# Out:
# 1218 1218
# ['형', '다는', '이어', '이날', '없', '으며', '신', '주요', '열', '아서']

# %%
# 데이터 토큰화 및 단어사전 구축
komoran= Komoran()

# %%
train_tokens = [[token for token in komoran.morphs(sentence) if token not in stopwords] for sentence in train.text]
test_tokens =  [[token for token in komoran.morphs(sentence) if token not in stopwords] for sentence in test.text]

# %%
len(train_tokens), len(test_tokens)
# Out:
# (36974, 4108)

# %%
vocab = build_vocab(corpus=train_tokens, n_vocab=20000, special_tokens=['<PAD>', '<UNK>'])
token_to_id = {token:idx for idx, token in enumerate(vocab)}
id_to_token = {idx:token for idx, token in enumerate(vocab)}

print(vocab[:20])
print(len(vocab))

print(token_to_id)
print(id_to_token)
# Out:
# ['<PAD>', '<UNK>', '원', '억', '금융', '통하', '기업', '사업', '지나', '시장', '대하', '지난해', '관계자', '지역', '올해', '성', '국내', '명', '고객', '대전']
# 20002
�', 278: '기차', 279: '보유', 280: '거나', 281: '신용', 282: '피해', 283: '문화', 284: '교수', 285: '배터리', 286: '본부', 287: '혜택', 288: '탄소', 289: '지급', 290: '이하', 291: '㎡', 292: '소상', 293: '모든', 294: '입', 295: '모바일', 296: '확산', 297: '변화', 298: '뱅크', 299: '구조', 300: '겠', 301: '회의', 302: '나서', 303: '소비', 304: '공동', 305: '당국', 306: '유지', 307: '농협', 308: '마련', 309: '청년', 310: '전문가', 311: '가상', 312: '장기', 313: '소득', 314: '연', 315: '오후', 316: '건강', 317: '인증', 318: '구축', 319: '발전', 320: '채용', 321: '가치', 322: '모델', 323: '유통', 324: '핵심', 325: '구역', 326: '펀드', 327: '대응', 328: '어렵', 329: '집', 330: '이사', 331: '스마트', 332: '내용', 333: '나오', 334: '인수', 335: '온', 336: '현대차', 337: '동기', 338: '수입', 339: '못하', 340: '선물', 341: '현지', 342: '박', 343: '송', 344: '밝히', 345: '디자인', 346: '분양', 347: '하반기', 348: '처음', 349: '공개', 350: '결정', 351: '설립', 352: '기획', 353: '법인', 354: '공간', 355: '비율', 356: '사진', 357: '없이', 358: '일본', 359: '높이', 360: '호텔', 361: '심사', 362: '노조', 363: '낮', 364: '제조', 365: '물', 366: '미디어', 367: '효과', 368: '생', 369: '우려', 370: '주가', 371: '이어지', 372: ' ...

# %%
# 단어 사전 저장
with open('vocab.pkl', 'wb') as f:
    pickle.dump(token_to_id, f)

print("단어 사전이 저장되었습니다.")
# Out:
# 단어 사전이 저장되었습니다.

# %%
# 정수 인코딩 및 패딩
unk_id = token_to_id['<UNK>']
train_ids = [[token_to_id.get(token, unk_id)for token in text] for text in train_tokens]
test_ids = [[token_to_id.get(token, unk_id)for token in text] for text in test_tokens]

max_length = 200
pad_id = token_to_id['<PAD>']
train_ids = pad_sequences(train_ids, max_length, pad_id)
test_ids = pad_sequences(test_ids, max_length, pad_id)

print(train_ids[0])
print(test_ids[0])
# Out:
# [   59  4339     1  1316   766  2773     8 14800   371   311   426    36
#  14379   717  6827  1490  1147  5158  1143  3272   665   311   426     9
#   3086    30   766    36   797  1197   766  8417  1389     1   159  4245
#      1   311   426  4731    24  4390   311   426  6423   300    83   876
#      4   305  2690 15279   161  2182  4660   300   294   577     4   547
#    311   426   426     4    85   155   311   426   311   426  6094   321
#   1368   155   238    41   178    40   300     4   960   311   426   178
#   5486   165   556   311   426    85  1003  1519  1917  1003  1664  1340
#   3782 17591   311   426   178   308   960  4732   311   426    85  1290
#   1340    52    22   178  1290  1340   771   420  1398  1529   121  5659
#     65     4   178   771  1398  1529   209   420    10  1398  1529   748
#   1344   794   535  5626   178  7018   399   311   426   771    44   241
#   2684    85  1290  1340    35   963    24    55   174   358   311   426
#   1368   420   421   178   161  2182  8839 10260   178   300 12967   766
#    311   426   175  4076     4   305    85   856  1582    85  3987  3481
#   1622    33    45   319   203     4   305  5626   178  4391     1 12396
#      9     0     0     0     0     0     0     0]
# [ 4917     4  1051   313   100   292   244  6310   423   236   573   312
#   1438  5632    27     5   108    38    97  2141  1175  1175     4  1908
#    597   313   100  1815    13   351  1175     4  1908   597   281  4406
#   2595  3347   313  2592   824    32    23  4429  3517    18   729    14
#   1175     4  1908   597  1326   661  4917     4  1060   729     4    97
#    322  3046  4797   108    15  8281   195  4917     4    71    37    23
#     71   810   912    27  1175   153   729     8     4    41   205 12927
#    714   351    79   705   292   244  5122    98  4076  1275  1618   814
#     23   281     4  2189   912  6552   642    16     4    41    67  4032
#   1438     1   729     4    41   205     8    52   112    23  1438  4169
#     37   255  1438    37    65    61   146   722    65    32    23   423
#    146  4169    37  4212    32  5586     1   852   590  4432   108   165
#    194   729     3     2  5586     1   852   590  3404  4432   786  1180
#   1175   313   100   750  2158 13402  1033   111  6817   155     4  2189
#    100   729    23   281    96     4  2189   912  6552  1062   642  1438
#     37  1275   313   281   646  1090    23  2990    57  3305   909    23
#   1776     4    41   607    99    71    37    23]

# %%
# 데이터로더 적용
batch_size=32
train_ids = torch.tensor(train_ids)
test_ids = torch.tensor(test_ids)

train_labels = torch.tensor(train.label.values, dtype=torch.float32)
test_labels = torch.tensor(test.label.values, dtype=torch.float32)

train_dataset = TensorDataset(train_ids, train_labels)
test_dataset = TensorDataset(test_ids, test_labels)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# 손실함수와 최적화함수 정의
n_vocab = len(token_to_id)
hidden_dim = 64
embedding_dim = 128
n_layers = 2

device = 'cuda' if torch.cuda.is_available() else 'cpu'

classifier = SentenceClassifier(n_vocab=n_vocab, hidden_dim=hidden_dim, 
                                embedding_dim=embedding_dim, n_layers=n_layers).to(device)
criterion = nn.BCEWithLogitsLoss().to(device)
optimizer = optim.Adam(classifier.parameters(), lr=0.001)
# 최적화 스케줄링 인스턴스 생성
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', patience=8, verbose=True)
# Out:
# c:\Users\kdp\anaconda3\envs\TEXT_018_230_38\lib\site-packages\torch\optim\lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "

# %%
# 저장 경로
SAVE_PATH = './models/'
# 경로상 폴더 존재 여부 체크
if not os.path.exists(SAVE_PATH) : os.makedirs(SAVE_PATH)   # 폴더 / 폴더 / ...  하위폴더까지 생성

# %%
epochs = 100
interval = 500
for epoch in range(epochs):
    print(f'[{epoch+1}/{epochs}]')
    train_model(classifier, train_loader, criterion, optimizer, device, interval)
    loss_val, score_val = test_model(classifier,test_loader, criterion, device)

    # 최적화 스케줄러 인스턴스 업데이트
    scheduler.step(score_val)
    print(f'scheduler.num_bad_epochs => {scheduler.num_bad_epochs}')

    SAVE_MODEL = SAVE_PATH + f'loss_{loss_val:.3f}_score{score_val:.3f}.pth'
    torch.save(classifier, SAVE_MODEL)

    if scheduler.num_bad_epochs >= scheduler.patience :
        print(f'성능 개선이 없어서 {scheduler.patience} EPOCH에 조기 종료함!')
        break
# Out:
# [1/100]
# Train Loss 0 : 0.6970170736312866
# Train Loss 500 : 0.6915267961705754
# Train Loss 1000 : 0.68853935995302
# Val Loss : 0.6793552064156347, Val Accuracy : 0.565238558909445
# scheduler.num_bad_epochs => 0
# [2/100]
# Train Loss 0 : 0.6648733615875244
# Train Loss 500 : 0.6786463694896051
# Train Loss 1000 : 0.6761855043016828
# Val Loss : 0.6560969433581182, Val Accuracy : 0.6131937682570594
# scheduler.num_bad_epochs => 0
# [3/100]
# Train Loss 0 : 0.6326393485069275
# Train Loss 500 : 0.6126663473075973
# Train Loss 1000 : 0.5767346455917491
# Val Loss : 0.5133480073869691, Val Accuracy : 0.7716650438169426
# scheduler.num_bad_epochs => 0
# [4/100]
# Train Loss 0 : 0.45991286635398865
# Train Loss 500 : 0.4586044839934675
# Train Loss 1000 : 0.45697238425036646
# Val Loss : 0.48696839162545613, Val Accuracy : 0.7850535540408958
# scheduler.num_bad_epochs => 0
# [5/100]
# Train Loss 0 : 0.3949907422065735
# Train Loss 500 : 0.4079212110318586
# Train Loss 1000 : 0.4074600317499616
# Val Loss : 0.4841546349862749, Val Accuracy : 0.7882181110029212
# scheduler.num_bad_epochs => 0
# [6/100]
# Train Loss 0 : 0.31181207299232483
# Train Loss 500 : 0.3636024894709597
# Train Loss 1000 : 0.3688951824065093
# Val Loss : 0.5031869884493739, Val Accuracy : 0.7877312560856865
# scheduler.num_bad_epochs => 1
# [7/100]
# Train Loss 0 : 0.3493209481239319
# Train Loss 500 : 0.32787760995521753
# Train Loss 1000 : 0.3306930824801638
# Val Loss : 0.5207960722866909, Val Accuracy : 0.7760467380720545
# scheduler.num_bad_epochs => 2
# [8/100]
# Train Loss 0 : 0.47772401571273804
# Train Loss 500 : 0.2904783496094083
# Train Loss 1000 : 0.29866731123669404
# Val Loss : 0.5422819309918455, Val Accuracy : 0.7736124634858812
# scheduler.num_bad_epochs => 3
# [9/100]
# Train Loss 0 : 0.31468480825424194
# Train Loss 500 : 0.2572763624141911
# Train Loss 1000 : 0.26359578552511664
# Val Loss : 0.579788249014884, Val Accuracy : 0.7643622200584226
# scheduler.num_bad_epochs => 4
# [10/100]
# Train Loss 0 : 0.28087320923805237
# Train Loss 500 : 0.2385057947131807
# Train Loss 1000 : 0.24349437169470153
# Val Loss : 0.6765547394752502, Val Accuracy : 0.7638753651411879
# scheduler.num_bad_epochs => 5
# [11/100]
# Train Loss 0 : 0.4605688452720642
# Train Loss 500 : 0.22315594495205346
# Train Loss 1000 : 0.2268000003415626
# Val Loss : 0.6531102489535661, Val Accuracy : 0.750730282375852
# scheduler.num_bad_epochs => 6
# [12/100]
# Train Loss 0 : 0.22021307051181793
# Train Loss 500 : 0.2052378915770801
# Train Loss 1000 : 0.20777752831369847
# Val Loss : 0.7218529244437236, Val Accuracy : 0.7541382667964946
# scheduler.num_bad_epochs => 7
# [13/100]
# Train Loss 0 : 0.13387949764728546
# Train Loss 500 : 0.18831564671175924
# Train Loss 1000 : 0.1955168076812268
# Val Loss : 0.6930697898474313, Val Accuracy : 0.7629016553067186
# scheduler.num_bad_epochs => 8
# 성능 개선이 없어서 8 EPOCH에 조기 종료함!
